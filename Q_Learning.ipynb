# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_datareader import data as pdr
company = 'ABBV'
df_full = pd.read_csv('/content/drive/MyDrive/TFM/' + company + '.csv')
df_full.head()
sns.set()

# %%
from collections import deque
import random
from tensorflow.python.framework import ops
# %tensorflow_version 1.x

df= df_full.copy()
name = 'Q-learning agent'

class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        ops.reset_default_graph()
        self.sess=tf.compat.v1.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 256, activation = tf.nn.relu)
        self.logits = tf.layers.dense(feed, self.action_size)
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %% [markdown]
# You can change the "initial money", as well as all other settings to whatever you please!

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

close = df.Close.values.tolist()
initial_money = 1000
window_size = 320
skip = 2
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 30, checkpoint = 5, initial_money = initial_money)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py:1771: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
# /usr/local/lib/python3.7/dist-packages/keras/legacy_tf_layers/core.py:255: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   return layer.apply(inputs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
# epoch: 5, total rewards: 1150.830048.3, cost: 0.666930, total money: 1899.760055
# epoch: 10, total rewards: 728.080101.3, cost: 0.571576, total money: 1728.080101
# epoch: 15, total rewards: 156.210109.3, cost: 0.351928, total money: 1156.210109
# epoch: 20, total rewards: 277.830088.3, cost: 0.335336, total money: 1277.830088
# epoch: 25, total rewards: 301.990102.3, cost: 0.294295, total money: 1301.990102
# epoch: 30, total rewards: 249.650068.3, cost: 0.285066, total money: 1249.650068

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 6: buy 1 unit at price 34.000000, total balance 966.000000
# day 8, sell 1 unit at price 34.090000, investment 0.264706 %, total balance 1000.090000,
# day 12: buy 1 unit at price 37.320000, total balance 962.770000
# day 18, sell 1 unit at price 37.310001, investment -0.026793 %, total balance 1000.080001,
# day 24: buy 1 unit at price 37.139999, total balance 962.940002
# day 26, sell 1 unit at price 36.250000, investment -2.396336 %, total balance 999.190002,
# day 28: buy 1 unit at price 35.419998, total balance 963.770004
# day 32: buy 1 unit at price 38.189999, total balance 925.580005
# day 34, sell 1 unit at price 38.779999, investment 9.486169 %, total balance 964.360004,
# day 40: buy 1 unit at price 37.810001, total balance 926.550003
# day 42: buy 1 unit at price 37.509998, total balance 889.040005
# day 44: buy 1 unit at price 37.490002, total balance 851.550003
# day 46: buy 1 unit at price 37.669998, total balance 813.880005
# day 50, sell 1 unit at price 38.500000, investment 0.811733 %, total balance 852.380005,
# day 56: buy 1 unit at price 39.320000, total balance 813.060005
# day 58, sell 1 unit at price 40.150002, investment 6.188841 %, total balance 853.210007,
# day 60: buy 1 unit at price 41.119999, total balance 812.090008
# day 62: buy 1 unit at price 40.570000, total balance 771.520008
# day 66, sell 1 unit at price 42.549999, investment 13.436420 %, total balance 814.070007,
# day 68: buy 1 unit at price 43.200001, total balance 770.870006
# day 70, sell 1 unit at price 41.439999, investment 10.536134 %, total balance 812.310005,
# day 74: buy 1 unit at price 42.389999, total balance 769.920006
# day 76, sell 1 unit at price 45.139999, investment 19.830107 %, total balance 815.060005,
# day 78: buy 1 unit at price 44.240002, total balance 770.820003
# day 82: buy 1 unit at price 45.549999, total balance 725.270004
# day 84, sell 1 unit at price 44.680000, investment 13.631740 %, total balance 769.950004,
# day 86, sell 1 unit at price 44.910000, investment 9.216929 %, total balance 814.860004,
# day 92, sell 1 unit at price 46.029999, investment 13.458218 %, total balance 860.890003,
# day 94, sell 1 unit at price 47.169998, investment 9.189808 %, total balance 908.060001,
# day 100: buy 1 unit at price 45.389999, total balance 862.670002
# day 104: buy 1 unit at price 43.360001, total balance 819.310001
# day 116: buy 1 unit at price 43.040001, total balance 776.270000
# day 118, sell 1 unit at price 42.619999, investment 0.542581 %, total balance 818.889999,
# day 128, sell 1 unit at price 43.680000, investment -1.265827 %, total balance 862.569999,
# day 130, sell 1 unit at price 43.910000, investment -3.600437 %, total balance 906.479999,
# day 132, sell 1 unit at price 45.049999, investment -0.749064 %, total balance 951.529998,
# day 134, sell 1 unit at price 43.810001, investment 1.037823 %, total balance 995.339999,
# day 136: buy 1 unit at price 44.320000, total balance 951.019999
# day 138, sell 1 unit at price 44.970001, investment 4.484201 %, total balance 995.990000,
# day 142: buy 1 unit at price 44.790001, total balance 951.199999
# day 144: buy 1 unit at price 44.700001, total balance 906.499998
# day 146: buy 1 unit at price 45.250000, total balance 861.249998
# day 148, sell 1 unit at price 44.709999, investment 0.879962 %, total balance 905.959997,
# day 152, sell 1 unit at price 44.709999, investment -0.178616 %, total balance 950.669996,
# day 154: buy 1 unit at price 44.930000, total balance 905.739996
# day 156: buy 1 unit at price 43.209999, total balance 862.529997
# day 158: buy 1 unit at price 43.369999, total balance 819.159998
# day 160: buy 1 unit at price 42.310001, total balance 776.849997
# day 162, sell 1 unit at price 43.430000, investment -2.841165 %, total balance 820.279997,
# day 164: buy 1 unit at price 42.630001, total balance 777.649996
# day 170, sell 1 unit at price 43.509998, investment -3.845308 %, total balance 821.159994,
# day 174, sell 1 unit at price 44.950001, investment 0.044516 %, total balance 866.109995,
# day 178, sell 1 unit at price 47.599998, investment 10.159683 %, total balance 913.709993,
# day 184: buy 1 unit at price 45.330002, total balance 868.379991
# day 188, sell 1 unit at price 45.799999, investment 5.602951 %, total balance 914.179990,
# day 190, sell 1 unit at price 46.009998, investment 8.744970 %, total balance 960.189988,
# day 196, sell 1 unit at price 45.650002, investment 7.084215 %, total balance 1005.839990,
# day 198, sell 1 unit at price 46.080002, investment 1.654533 %, total balance 1051.919992,
# day 216: buy 1 unit at price 48.029999, total balance 1003.889993
# day 218, sell 1 unit at price 47.480000, investment -1.145116 %, total balance 1051.369993,
# day 234: buy 1 unit at price 49.759998, total balance 1001.609995
# day 238: buy 1 unit at price 52.669998, total balance 948.939997
# day 240, sell 1 unit at price 52.369999, investment 5.245179 %, total balance 1001.309996,
# day 242, sell 1 unit at price 53.630001, investment 1.822675 %, total balance 1054.939997,
# day 248: buy 1 unit at price 52.990002, total balance 1001.949995
# day 252, sell 1 unit at price 51.980000, investment -1.906024 %, total balance 1053.929995,
# day 286: buy 1 unit at price 51.040001, total balance 1002.889994
# day 288, sell 1 unit at price 50.720001, investment -0.626959 %, total balance 1053.609995,
# day 292: buy 1 unit at price 50.090000, total balance 1003.519995
# day 294: buy 1 unit at price 51.700001, total balance 951.819994
# day 296: buy 1 unit at price 51.459999, total balance 900.359995
# day 302, sell 1 unit at price 51.980000, investment 3.773208 %, total balance 952.339995,
# day 304, sell 1 unit at price 53.110001, investment 2.727273 %, total balance 1005.449996,
# day 306, sell 1 unit at price 53.459999, investment 3.886514 %, total balance 1058.909995,
# day 308: buy 1 unit at price 51.689999, total balance 1007.219996
# day 312: buy 1 unit at price 51.400002, total balance 955.819994
# day 314: buy 1 unit at price 53.340000, total balance 902.479994
# day 318, sell 1 unit at price 49.099998, investment -5.010642 %, total balance 951.579992,
# day 320: buy 1 unit at price 47.349998, total balance 904.229994
# day 322: buy 1 unit at price 46.830002, total balance 857.399992
# day 324: buy 1 unit at price 48.119999, total balance 809.279993
# day 328: buy 1 unit at price 50.139999, total balance 759.139994
# day 332: buy 1 unit at price 51.369999, total balance 707.769995
# day 338, sell 1 unit at price 52.790001, investment 2.704278 %, total balance 760.559996,
# day 342, sell 1 unit at price 52.200001, investment -2.137231 %, total balance 812.759997,
# day 346, sell 1 unit at price 54.110001, investment 14.276670 %, total balance 866.869998,
# day 348, sell 1 unit at price 53.270000, investment 13.751864 %, total balance 920.139998,
# day 350, sell 1 unit at price 53.950001, investment 12.115549 %, total balance 974.089999,
# day 352, sell 1 unit at price 54.070000, investment 7.838056 %, total balance 1028.159999,
# day 358, sell 1 unit at price 55.299999, investment 7.650380 %, total balance 1083.459998,
# day 364: buy 1 unit at price 54.160000, total balance 1029.299998
# day 366, sell 1 unit at price 54.299999, investment 0.258492 %, total balance 1083.599997,
# day 374: buy 1 unit at price 56.790001, total balance 1026.809996
# day 378, sell 1 unit at price 58.220001, investment 2.518049 %, total balance 1085.029997,
# day 380: buy 1 unit at price 55.689999, total balance 1029.339998
# day 384, sell 1 unit at price 54.849998, investment -1.508352 %, total balance 1084.189996,
# day 398: buy 1 unit at price 52.480000, total balance 1031.709996
# day 402, sell 1 unit at price 52.430000, investment -0.095274 %, total balance 1084.139996,
# day 404: buy 1 unit at price 53.310001, total balance 1030.829995
# day 408, sell 1 unit at price 53.900002, investment 1.106736 %, total balance 1084.729997,
# day 414: buy 1 unit at price 55.869999, total balance 1028.859998
# day 416: buy 1 unit at price 55.700001, total balance 973.159997
# day 418: buy 1 unit at price 55.279999, total balance 917.879998
# day 420: buy 1 unit at price 55.509998, total balance 862.370000
# day 428: buy 1 unit at price 57.930000, total balance 804.440000
# day 430, sell 1 unit at price 59.619999, investment 6.712010 %, total balance 864.059999,
# day 434, sell 1 unit at price 57.560001, investment 3.339318 %, total balance 921.620000,
# day 440: buy 1 unit at price 57.230000, total balance 864.390000
# day 442, sell 1 unit at price 58.689999, investment 6.168596 %, total balance 923.079999,
# day 444: buy 1 unit at price 56.650002, total balance 866.429997
# day 448: buy 1 unit at price 53.619999, total balance 812.809998
# day 450, sell 1 unit at price 54.630001, investment -1.585295 %, total balance 867.439999,
# day 452: buy 1 unit at price 53.369999, total balance 814.070000
# day 454, sell 1 unit at price 56.290001, investment -2.831001 %, total balance 870.360001,
# day 456: buy 1 unit at price 59.520000, total balance 810.840001
# day 462, sell 1 unit at price 63.459999, investment 10.885897 %, total balance 874.300000,
# day 464: buy 1 unit at price 62.660000, total balance 811.640000
# day 466, sell 1 unit at price 62.709999, investment 10.697258 %, total balance 874.349999,
# day 470: buy 1 unit at price 63.759998, total balance 810.590001
# day 476: buy 1 unit at price 65.190002, total balance 745.399999
# day 478: buy 1 unit at price 67.779999, total balance 677.620000
# day 482, sell 1 unit at price 69.110001, investment 28.888479 %, total balance 746.730001,
# day 484: buy 1 unit at price 68.500000, total balance 678.230001
# day 492, sell 1 unit at price 65.620003, investment 22.952978 %, total balance 743.850004,
# day 494, sell 1 unit at price 66.570000, investment 11.844758 %, total balance 810.420004,
# day 496: buy 1 unit at price 67.709999, total balance 742.710005
# day 500: buy 1 unit at price 66.980003, total balance 675.730002
# day 502: buy 1 unit at price 66.300003, total balance 609.429999
# day 504, sell 1 unit at price 65.889999, investment 5.154802 %, total balance 675.319998,
# day 510: buy 1 unit at price 65.760002, total balance 609.559996
# day 520, sell 1 unit at price 63.099998, investment -1.035132 %, total balance 672.659994,
# day 528: buy 1 unit at price 56.900002, total balance 615.759992
# day 530, sell 1 unit at price 56.889999, investment -12.732018 %, total balance 672.649991,
# day 532, sell 1 unit at price 57.049999, investment -15.830629 %, total balance 729.699990,
# day 534, sell 1 unit at price 58.720001, investment -14.277371 %, total balance 788.419991,
# day 542, sell 1 unit at price 60.500000, investment -10.648352 %, total balance 848.919991,
# day 544, sell 1 unit at price 59.619999, investment -10.988360 %, total balance 908.539990,
# day 546: buy 1 unit at price 56.860001, total balance 851.679989
# day 548: buy 1 unit at price 55.540001, total balance 796.139988
# day 550, sell 1 unit at price 56.619999, investment -14.600307 %, total balance 852.759987,
# day 552: buy 1 unit at price 58.000000, total balance 794.759987
# day 554, sell 1 unit at price 59.730000, investment -9.169711 %, total balance 854.489987,
# day 558, sell 1 unit at price 60.480000, investment 6.291736 %, total balance 914.969987,
# day 560, sell 1 unit at price 58.220001, investment 2.391840 %, total balance 973.189988,
# day 562, sell 1 unit at price 57.650002, investment 3.799065 %, total balance 1030.839990,
# day 570: buy 1 unit at price 60.320000, total balance 970.519990
# day 574: buy 1 unit at price 62.029999, total balance 908.489991
# day 576: buy 1 unit at price 62.290001, total balance 846.199990
# day 578, sell 1 unit at price 63.610001, investment 9.672416 %, total balance 909.809991,
# day 580: buy 1 unit at price 64.250000, total balance 845.559991
# day 582: buy 1 unit at price 65.019997, total balance 780.539994
# day 600, sell 1 unit at price 65.650002, investment 8.836210 %, total balance 846.189996,
# day 602: buy 1 unit at price 66.099998, total balance 780.089998
# day 608, sell 1 unit at price 67.010002, investment 8.028378 %, total balance 847.100000,
# day 616, sell 1 unit at price 66.910004, investment 7.416926 %, total balance 914.010004,
# day 618, sell 1 unit at price 67.769997, investment 5.478595 %, total balance 981.780001,
# day 620: buy 1 unit at price 69.480003, total balance 912.299998
# day 622: buy 1 unit at price 70.019997, total balance 842.280001
# day 626: buy 1 unit at price 67.180000, total balance 775.100001
# day 628, sell 1 unit at price 68.510002, investment 5.367587 %, total balance 843.610003,
# day 634, sell 1 unit at price 69.230003, investment 4.735257 %, total balance 912.840006,
# day 640, sell 1 unit at price 70.800003, investment 1.899827 %, total balance 983.640009,
# day 644, sell 1 unit at price 68.080002, investment -2.770630 %, total balance 1051.720011,
# day 646: buy 1 unit at price 71.230003, total balance 980.490008
# day 648, sell 1 unit at price 70.160004, investment 4.435850 %, total balance 1050.650012,
# day 652: buy 1 unit at price 70.300003, total balance 980.350009
# day 654, sell 1 unit at price 68.620003, investment -3.664186 %, total balance 1048.970012,
# day 656, sell 1 unit at price 68.250000, investment -2.916078 %, total balance 1117.220012,
# day 658: buy 1 unit at price 68.540001, total balance 1048.680011
# day 660, sell 1 unit at price 69.370003, investment 1.210975 %, total balance 1118.050014,
# day 662: buy 1 unit at price 68.589996, total balance 1049.460018
# day 670: buy 1 unit at price 62.410000, total balance 987.050018
# day 674, sell 1 unit at price 59.770000, investment -12.859012 %, total balance 1046.820018,
# day 676, sell 1 unit at price 59.259998, investment -5.047271 %, total balance 1106.080016,
# day 678: buy 1 unit at price 59.349998, total balance 1046.730018
# day 682: buy 1 unit at price 59.860001, total balance 986.870017
# day 684, sell 1 unit at price 59.389999, investment 0.067398 %, total balance 1046.260016,
# day 688, sell 1 unit at price 55.740002, investment -6.882725 %, total balance 1102.000018,
# day 690: buy 1 unit at price 52.790001, total balance 1049.210017
# day 692, sell 1 unit at price 55.130001, investment 4.432658 %, total balance 1104.340018,
# day 700: buy 1 unit at price 53.799999, total balance 1050.540019
# day 702, sell 1 unit at price 56.139999, investment 4.349442 %, total balance 1106.680018,
# day 704: buy 1 unit at price 56.160000, total balance 1050.520018
# day 706, sell 1 unit at price 53.830002, investment -4.148857 %, total balance 1104.350020,
# day 708: buy 1 unit at price 50.340000, total balance 1054.010020
# day 712: buy 1 unit at price 54.099998, total balance 999.910022
# day 714, sell 1 unit at price 63.380001, investment 25.903856 %, total balance 1063.290023,
# day 720: buy 1 unit at price 62.299999, total balance 1000.990024
# day 724: buy 1 unit at price 60.009998, total balance 940.980026
# day 726, sell 1 unit at price 60.990002, investment 12.735683 %, total balance 1001.970028,
# day 728: buy 1 unit at price 61.110001, total balance 940.860027
# day 736: buy 1 unit at price 56.119999, total balance 884.740028
# day 740: buy 1 unit at price 56.029999, total balance 828.710029
# day 748: buy 1 unit at price 56.200001, total balance 772.510028
# day 750, sell 1 unit at price 58.580002, investment -5.971103 %, total balance 831.090030,
# day 754: buy 1 unit at price 59.799999, total balance 771.290031
# day 756, sell 1 unit at price 57.610001, investment -3.999329 %, total balance 828.900032,
# day 758, sell 1 unit at price 57.380001, investment -6.103747 %, total balance 886.280033,
# day 760: buy 1 unit at price 55.650002, total balance 830.630031
# day 762: buy 1 unit at price 54.840000, total balance 775.790031
# day 764, sell 1 unit at price 54.560001, investment -2.779754 %, total balance 830.350032,
# day 768, sell 1 unit at price 58.360001, investment 4.158490 %, total balance 888.710033,
# day 772, sell 1 unit at price 57.110001, investment 1.619217 %, total balance 945.820034,
# day 774, sell 1 unit at price 54.900002, investment -8.193975 %, total balance 1000.720036,
# day 776, sell 1 unit at price 53.950001, investment -3.054809 %, total balance 1054.670037,
# day 780, sell 1 unit at price 52.889999, investment -3.555801 %, total balance 1107.560036,
# day 790: buy 1 unit at price 55.070000, total balance 1052.490036
# day 792, sell 1 unit at price 56.200001, investment 2.051936 %, total balance 1108.690037,
# day 808: buy 1 unit at price 56.570000, total balance 1052.120037
# day 810: buy 1 unit at price 57.500000, total balance 994.620037
# day 818, sell 1 unit at price 59.209999, investment 4.666783 %, total balance 1053.830036,
# day 820, sell 1 unit at price 59.889999, investment 4.156520 %, total balance 1113.720035,
# day 834: buy 1 unit at price 60.930000, total balance 1052.790035
# day 836: buy 1 unit at price 61.200001, total balance 991.590034
# day 838: buy 1 unit at price 61.439999, total balance 930.150035
# day 840: buy 1 unit at price 61.459999, total balance 868.690036
# day 848, sell 1 unit at price 62.450001, investment 2.494668 %, total balance 931.140037,
# day 854, sell 1 unit at price 60.700001, investment -0.816993 %, total balance 991.840038,
# day 856, sell 1 unit at price 61.900002, investment 0.748703 %, total balance 1053.740040,
# day 860, sell 1 unit at price 65.089996, investment 5.906276 %, total balance 1118.830036,
# day 864: buy 1 unit at price 61.730000, total balance 1057.100036
# day 866: buy 1 unit at price 61.000000, total balance 996.100036
# day 870, sell 1 unit at price 60.900002, investment -1.344562 %, total balance 1057.000038,
# day 872, sell 1 unit at price 60.110001, investment -1.459015 %, total balance 1117.110039,
# day 884: buy 1 unit at price 63.430000, total balance 1053.680039
# day 886: buy 1 unit at price 64.349998, total balance 989.330041
# day 890: buy 1 unit at price 63.320000, total balance 926.010041
# day 892, sell 1 unit at price 63.320000, investment -0.173420 %, total balance 989.330041,
# day 894: buy 1 unit at price 63.889999, total balance 925.440042
# day 900: buy 1 unit at price 66.230003, total balance 859.210039
# day 910, sell 1 unit at price 67.190002, investment 4.413371 %, total balance 926.400041,
# day 916: buy 1 unit at price 67.010002, total balance 859.390039
# day 918: buy 1 unit at price 65.059998, total balance 794.330041
# day 928, sell 1 unit at price 64.059998, investment 1.168664 %, total balance 858.390039,
# day 930, sell 1 unit at price 64.080002, investment 0.297391 %, total balance 922.470041,
# day 932: buy 1 unit at price 63.340000, total balance 859.130041
# day 936, sell 1 unit at price 63.279999, investment -4.454181 %, total balance 922.410040,
# day 946: buy 1 unit at price 63.000000, total balance 859.410040
# day 948, sell 1 unit at price 62.830002, investment -6.237875 %, total balance 922.240042,
# day 950: buy 1 unit at price 63.310001, total balance 858.930041
# day 956, sell 1 unit at price 61.549999, investment -5.395019 %, total balance 920.480040,
# day 958: buy 1 unit at price 61.759998, total balance 858.720042
# day 964, sell 1 unit at price 57.599998, investment -9.062207 %, total balance 916.320040,
# day 968: buy 1 unit at price 55.889999, total balance 860.430041
# day 970, sell 1 unit at price 58.910000, investment -6.492063 %, total balance 919.340041,
# day 976, sell 1 unit at price 62.869999, investment -0.694996 %, total balance 982.210040,
# day 978: buy 1 unit at price 61.700001, total balance 920.510039
# day 982, sell 1 unit at price 60.180000, investment -2.558287 %, total balance 980.690039,
# day 984: buy 1 unit at price 59.459999, total balance 921.230040
# day 986: buy 1 unit at price 60.799999, total balance 860.430041
# day 988: buy 1 unit at price 59.430000, total balance 801.000041
# day 990: buy 1 unit at price 61.619999, total balance 739.380042
# day 996, sell 1 unit at price 61.669998, investment 10.341741 %, total balance 801.050040,
# day 1000: buy 1 unit at price 62.160000, total balance 738.890040
# day 1004: buy 1 unit at price 62.500000, total balance 676.390040
# day 1012: buy 1 unit at price 64.209999, total balance 612.180041
# day 1016, sell 1 unit at price 61.990002, investment 0.470018 %, total balance 674.170043,
# day 1020: buy 1 unit at price 61.150002, total balance 613.020041
# day 1022: buy 1 unit at price 60.580002, total balance 552.440039
# day 1024: buy 1 unit at price 61.270000, total balance 491.170039
# day 1030, sell 1 unit at price 60.669998, investment 2.034980 %, total balance 551.840037,
# day 1032, sell 1 unit at price 60.560001, investment -0.394734 %, total balance 612.400038,
# day 1034, sell 1 unit at price 60.840000, investment 2.372539 %, total balance 673.240038,
# day 1040, sell 1 unit at price 61.770000, investment 0.243429 %, total balance 735.010038,
# day 1042: buy 1 unit at price 61.360001, total balance 673.650037
# day 1046, sell 1 unit at price 61.840000, investment -0.514801 %, total balance 735.490037,
# day 1048, sell 1 unit at price 63.250000, investment 1.200000 %, total balance 798.740037,
# day 1052: buy 1 unit at price 64.139999, total balance 734.600038
# day 1058: buy 1 unit at price 65.900002, total balance 668.700036
# day 1064: buy 1 unit at price 65.620003, total balance 603.080033
# day 1068: buy 1 unit at price 65.459999, total balance 537.620034
# day 1070, sell 1 unit at price 65.029999, investment 1.277060 %, total balance 602.650033,
# day 1072: buy 1 unit at price 64.959999, total balance 537.690034
# day 1074, sell 1 unit at price 65.540001, investment 7.179066 %, total balance 603.230035,
# day 1078, sell 1 unit at price 64.129997, investment 5.860011 %, total balance 667.360032,
# day 1080: buy 1 unit at price 63.650002, total balance 603.710030
# day 1082, sell 1 unit at price 63.779999, investment 4.096620 %, total balance 667.490029,
# day 1088: buy 1 unit at price 65.940002, total balance 601.550027
# day 1092, sell 1 unit at price 67.230003, investment 9.566496 %, total balance 668.780030,
# day 1094, sell 1 unit at price 66.209999, investment 3.227315 %, total balance 734.990029,
# day 1096: buy 1 unit at price 65.980003, total balance 669.010026
# day 1098: buy 1 unit at price 66.059998, total balance 602.950028
# day 1100, sell 1 unit at price 66.849998, investment 1.441572 %, total balance 669.800026,
# day 1102: buy 1 unit at price 65.629997, total balance 604.170029
# day 1108, sell 1 unit at price 66.059998, investment 0.670520 %, total balance 670.230027,
# day 1112, sell 1 unit at price 67.250000, investment 2.734496 %, total balance 737.480027,
# day 1114: buy 1 unit at price 67.870003, total balance 669.610024
# day 1118: buy 1 unit at price 69.529999, total balance 600.080025
# day 1120, sell 1 unit at price 70.519997, investment 8.559110 %, total balance 670.600022,
# day 1122, sell 1 unit at price 71.050003, investment 11.626081 %, total balance 741.650025,
# day 1124, sell 1 unit at price 71.220001, investment 8.007278 %, total balance 812.870026,
# day 1126: buy 1 unit at price 73.180000, total balance 739.690026
# day 1128: buy 1 unit at price 72.739998, total balance 666.950028
# day 1130: buy 1 unit at price 72.919998, total balance 594.030030
# day 1136, sell 1 unit at price 72.029999, investment 9.169439 %, total balance 666.060029,
# day 1140, sell 1 unit at price 72.629997, investment 9.945503 %, total balance 738.690026,
# day 1144, sell 1 unit at price 72.769997, investment 10.879172 %, total balance 811.460023,
# day 1152, sell 1 unit at price 69.910004, investment 3.005748 %, total balance 881.370027,
# day 1154: buy 1 unit at price 70.709999, total balance 810.660028
# day 1158: buy 1 unit at price 71.470001, total balance 739.190027
# day 1162, sell 1 unit at price 70.820000, investment 1.855316 %, total balance 810.010027,
# day 1166: buy 1 unit at price 69.959999, total balance 740.050028
# day 1170, sell 1 unit at price 72.110001, investment -1.462147 %, total balance 812.160029,
# day 1172, sell 1 unit at price 73.320000, investment 0.797363 %, total balance 885.480029,
# day 1174: buy 1 unit at price 73.919998, total balance 811.560031
# day 1178: buy 1 unit at price 77.050003, total balance 734.510028
# day 1180: buy 1 unit at price 85.339996, total balance 649.170032
# day 1182: buy 1 unit at price 87.750000, total balance 561.420032
# day 1186: buy 1 unit at price 85.320000, total balance 476.100032
# day 1190: buy 1 unit at price 87.480003, total balance 388.620029
# day 1192, sell 1 unit at price 85.349998, investment 17.046078 %, total balance 473.970027,
# day 1194: buy 1 unit at price 88.959999, total balance 385.010028
# day 1200, sell 1 unit at price 90.489998, investment 27.973412 %, total balance 475.500026,
# day 1204, sell 1 unit at price 91.419998, investment 27.913805 %, total balance 566.920024,
# day 1206: buy 1 unit at price 91.040001, total balance 475.880023
# day 1210: buy 1 unit at price 96.099998, total balance 379.780025
# day 1216: buy 1 unit at price 90.959999, total balance 288.820026
# day 1220, sell 1 unit at price 92.309998, investment 31.946826 %, total balance 381.130024,
# day 1234, sell 1 unit at price 94.720001, investment 28.138533 %, total balance 475.850025,
# day 1236: buy 1 unit at price 95.419998, total balance 380.430027
# day 1242, sell 1 unit at price 94.400002, investment 22.517843 %, total balance 474.830029,
# day 1244: buy 1 unit at price 95.949997, total balance 378.880032
# day 1246, sell 1 unit at price 96.300003, investment 12.842755 %, total balance 475.180035,
# day 1250, sell 1 unit at price 98.190002, investment 11.897438 %, total balance 573.370037,
# day 1258: buy 1 unit at price 96.709999, total balance 476.660038
# day 1260: buy 1 unit at price 99.949997, total balance 376.710041
# day 1262, sell 1 unit at price 101.110001, investment 18.506799 %, total balance 477.820042,
# day 1264, sell 1 unit at price 100.239998, investment 14.586185 %, total balance 578.060040,
# day 1266: buy 1 unit at price 99.269997, total balance 478.790043
# day 1270: buy 1 unit at price 103.809998, total balance 374.980045
# day 1272, sell 1 unit at price 106.489998, investment 19.705485 %, total balance 481.470043,
# day 1274: buy 1 unit at price 105.510002, total balance 375.960041
# day 1284, sell 1 unit at price 113.620003, investment 24.802287 %, total balance 489.580044,
# day 1286, sell 1 unit at price 111.300003, investment 15.816863 %, total balance 600.880047,
# day 1288, sell 1 unit at price 111.860001, investment 22.977135 %, total balance 712.740048,
# day 1296, sell 1 unit at price 121.540001, investment 27.373720 %, total balance 834.280049,
# day 1298: buy 1 unit at price 115.830002, total balance 718.450047
# day 1302: buy 1 unit at price 114.559998, total balance 603.890049
# day 1312, sell 1 unit at price 112.650002, investment 17.404904 %, total balance 716.540051,
# day 1314, sell 1 unit at price 98.099998, investment 1.437286 %, total balance 814.640049,
# day 1318: buy 1 unit at price 94.269997, total balance 720.370052
# day 1320, sell 1 unit at price 91.459999, investment -8.494245 %, total balance 811.830051,
# day 1322: buy 1 unit at price 92.940002, total balance 718.890049
# day 1328, sell 1 unit at price 92.120003, investment -7.202573 %, total balance 811.010052,
# day 1332, sell 1 unit at price 94.320000, investment -9.141699 %, total balance 905.330052,
# day 1336, sell 1 unit at price 91.360001, investment -13.411052 %, total balance 996.690053,
# day 1338, sell 1 unit at price 97.440002, investment -15.876716 %, total balance 1094.130055,
# day 1340: buy 1 unit at price 96.550003, total balance 997.580052
# day 1342, sell 1 unit at price 100.370003, investment -12.386518 %, total balance 1097.950055,
# day 1346, sell 1 unit at price 99.400002, investment 5.441822 %, total balance 1197.350057,
# day 1348: buy 1 unit at price 102.849998, total balance 1094.500059
# day 1350: buy 1 unit at price 105.889999, total balance 988.610060
# day 1354, sell 1 unit at price 105.980003, investment 14.030558 %, total balance 1094.590063,
# day 1362, sell 1 unit at price 98.940002, investment 2.475400 %, total balance 1193.530065,
# day 1366: buy 1 unit at price 99.980003, total balance 1093.550062
# day 1370: buy 1 unit at price 98.910004, total balance 994.640058
# day 1376: buy 1 unit at price 98.250000, total balance 896.390058
# day 1378: buy 1 unit at price 93.489998, total balance 802.900060
# day 1380, sell 1 unit at price 92.120003, investment -10.432664 %, total balance 895.020063,
# day 1382: buy 1 unit at price 92.430000, total balance 802.590063
# day 1388, sell 1 unit at price 97.040001, investment -8.357728 %, total balance 899.630064,
# day 1392, sell 1 unit at price 96.629997, investment -3.350676 %, total balance 996.260061,
# day 1394: buy 1 unit at price 95.410004, total balance 900.850057
# day 1396, sell 1 unit at price 89.949997, investment -9.058747 %, total balance 990.800054,
# day 1398: buy 1 unit at price 89.400002, total balance 901.400052
# day 1402: buy 1 unit at price 90.559998, total balance 810.840054
# day 1408, sell 1 unit at price 97.059998, investment -1.211198 %, total balance 907.900052,
# day 1410: buy 1 unit at price 93.730003, total balance 814.170049
# day 1412, sell 1 unit at price 95.800003, investment 2.470858 %, total balance 909.970052,
# day 1414, sell 1 unit at price 95.919998, investment 3.775828 %, total balance 1005.890050,
# day 1416, sell 1 unit at price 98.220001, investment 2.945181 %, total balance 1104.110051,
# day 1420, sell 1 unit at price 97.639999, investment 9.216999 %, total balance 1201.750050,
# day 1422: buy 1 unit at price 97.400002, total balance 1104.350048
# day 1424, sell 1 unit at price 97.260002, investment 7.398414 %, total balance 1201.610050,
# day 1426: buy 1 unit at price 96.790001, total balance 1104.820049
# day 1428, sell 1 unit at price 94.559998, investment 0.885517 %, total balance 1199.380047,
# day 1430: buy 1 unit at price 93.739998, total balance 1105.640049
# day 1434: buy 1 unit at price 93.239998, total balance 1012.400051
# day 1438: buy 1 unit at price 92.610001, total balance 919.790050
# day 1442, sell 1 unit at price 93.419998, investment -4.086246 %, total balance 1013.210048,
# day 1446, sell 1 unit at price 94.580002, investment -2.283293 %, total balance 1107.790050,
# day 1448: buy 1 unit at price 94.230003, total balance 1013.560047
# day 1452: buy 1 unit at price 94.809998, total balance 918.750049
# day 1456: buy 1 unit at price 90.690002, total balance 828.060047
# day 1462, sell 1 unit at price 84.269997, investment -10.102412 %, total balance 912.330044,
# day 1468, sell 1 unit at price 81.589996, investment -12.494640 %, total balance 993.920040,
# day 1472: buy 1 unit at price 82.580002, total balance 911.340038
# day 1476: buy 1 unit at price 88.790001, total balance 822.550037
# day 1478: buy 1 unit at price 88.220001, total balance 734.330036
# day 1480: buy 1 unit at price 90.139999, total balance 644.190037
# day 1482, sell 1 unit at price 89.480003, investment -3.379762 %, total balance 733.670040,
# day 1484, sell 1 unit at price 86.150002, investment -8.574765 %, total balance 819.820042,
# day 1486, sell 1 unit at price 86.239998, investment -9.039131 %, total balance 906.060040,
# day 1488, sell 1 unit at price 88.940002, investment -1.929650 %, total balance 995.000042,
# day 1492, sell 1 unit at price 90.550003, investment 9.651248 %, total balance 1085.550045,
# day 1496, sell 1 unit at price 88.169998, investment -0.698280 %, total balance 1173.720043,
# day 1500, sell 1 unit at price 84.930000, investment -3.729314 %, total balance 1258.650043,
# day 1502: buy 1 unit at price 83.519997, total balance 1175.130046
# day 1504: buy 1 unit at price 84.919998, total balance 1090.210048
# day 1508: buy 1 unit at price 91.120003, total balance 999.090045
# day 1512, sell 1 unit at price 89.070000, investment -1.187041 %, total balance 1088.160045,
# day 1516, sell 1 unit at price 88.199997, investment 5.603448 %, total balance 1176.360042,
# day 1520, sell 1 unit at price 85.550003, investment 0.741881 %, total balance 1261.910045,
# day 1522: buy 1 unit at price 89.500000, total balance 1172.410045
# day 1524: buy 1 unit at price 88.449997, total balance 1083.960048
# day 1532, sell 1 unit at price 78.529999, investment -13.816949 %, total balance 1162.490047,
# day 1538: buy 1 unit at price 79.930000, total balance 1082.560047
# day 1540, sell 1 unit at price 80.519997, investment -10.033523 %, total balance 1163.080044,
# day 1544: buy 1 unit at price 78.750000, total balance 1084.330044
# day 1546: buy 1 unit at price 80.290001, total balance 1004.040043
# day 1548, sell 1 unit at price 79.410004, investment -10.220456 %, total balance 1083.450047,
# day 1550, sell 1 unit at price 80.099998, investment 0.212684 %, total balance 1163.550045,
# day 1552, sell 1 unit at price 78.910004, investment 0.203180 %, total balance 1242.460049,
# day 1554, sell 1 unit at price 78.239998, investment -2.553248 %, total balance 1320.700047,
# day 1558: buy 1 unit at price 78.930000, total balance 1241.770047
# day 1560, sell 1 unit at price 81.339996, investment 3.053333 %, total balance 1323.110043,
# day 1562: buy 1 unit at price 80.820000, total balance 1242.290043
# day 1564, sell 1 unit at price 81.239998, investment 0.519671 %, total balance 1323.530041,
# day 1566: buy 1 unit at price 79.510002, total balance 1244.020039
# day 1570: buy 1 unit at price 80.589996, total balance 1163.430043
# day 1572, sell 1 unit at price 83.070000, investment 4.477422 %, total balance 1246.500043,
# day 1574, sell 1 unit at price 82.809998, investment 2.754687 %, total balance 1329.310041,
# day 1580: buy 1 unit at price 80.779999, total balance 1248.530042
# day 1586: buy 1 unit at price 78.660004, total balance 1169.870038
# day 1592, sell 1 unit at price 78.889999, investment -2.339688 %, total balance 1248.760037,
# day 1594, sell 1 unit at price 78.709999, investment 0.063558 %, total balance 1327.470036,
# day 1596: buy 1 unit at price 77.949997, total balance 1249.520039
# day 1598: buy 1 unit at price 77.910004, total balance 1171.610035
# day 1600, sell 1 unit at price 76.870003, investment -1.385496 %, total balance 1248.480038,
# day 1610, sell 1 unit at price 78.029999, investment 0.154017 %, total balance 1326.510037,
# day 1614: buy 1 unit at price 75.699997, total balance 1250.810040
# day 1616: buy 1 unit at price 77.059998, total balance 1173.750042
# day 1618: buy 1 unit at price 77.430000, total balance 1096.320042
# day 1620: buy 1 unit at price 78.169998, total balance 1018.150044
# day 1622, sell 1 unit at price 78.949997, investment 4.293263 %, total balance 1097.100041,
# day 1624, sell 1 unit at price 78.650002, investment 2.063333 %, total balance 1175.750043,
# day 1626: buy 1 unit at price 77.610001, total balance 1098.140042
# day 1632, sell 1 unit at price 70.000000, investment -9.595764 %, total balance 1168.140042,
# day 1634: buy 1 unit at price 73.400002, total balance 1094.740040
# day 1636, sell 1 unit at price 74.959999, investment -4.106434 %, total balance 1169.700039,
# day 1638: buy 1 unit at price 71.220001, total balance 1098.480038
# day 1642, sell 1 unit at price 70.279999, investment -9.444662 %, total balance 1168.760037,
# day 1644, sell 1 unit at price 69.160004, investment -5.776564 %, total balance 1237.920041,
# day 1646: buy 1 unit at price 68.250000, total balance 1169.670041
# day 1648, sell 1 unit at price 68.000000, investment -4.521203 %, total balance 1237.670041,
# day 1652, sell 1 unit at price 67.760002, investment -0.717946 %, total balance 1305.430043,
# day 1666: buy 1 unit at price 62.980000, total balance 1242.450043
# day 1668, sell 1 unit at price 66.559998, investment 5.684341 %, total balance 1309.010041,
# day 1670: buy 1 unit at price 67.540001, total balance 1241.470040
# day 1676, sell 1 unit at price 66.220001, investment -1.954397 %, total balance 1307.690041,
# day 1678: buy 1 unit at price 65.400002, total balance 1242.290039
# day 1688, sell 1 unit at price 71.599998, investment 9.480116 %, total balance 1313.890037,
# day 1690: buy 1 unit at price 71.669998, total balance 1242.220039
# day 1694: buy 1 unit at price 72.089996, total balance 1170.130043
# day 1696, sell 1 unit at price 74.849998, investment 4.437003 %, total balance 1244.980041,
# day 1698, sell 1 unit at price 73.230003, investment 1.581366 %, total balance 1318.210044,
# day 1706: buy 1 unit at price 73.629997, total balance 1244.580047
# day 1710, sell 1 unit at price 75.139999, investment 2.050797 %, total balance 1319.720046,
# day 1712: buy 1 unit at price 77.300003, total balance 1242.420043
# day 1714: buy 1 unit at price 77.750000, total balance 1164.670043
# day 1720, sell 1 unit at price 79.550003, investment 2.910737 %, total balance 1244.220046,
# day 1728, sell 1 unit at price 86.440002, investment 11.176851 %, total balance 1330.660048,
# day 1748: buy 1 unit at price 86.699997, total balance 1243.960051
# day 1750: buy 1 unit at price 87.839996, total balance 1156.120055
# day 1758: buy 1 unit at price 89.830002, total balance 1066.290053
# day 1762: buy 1 unit at price 89.550003, total balance 976.740050
# day 1766: buy 1 unit at price 89.519997, total balance 887.220053
# day 1768, sell 1 unit at price 89.059998, investment 2.722031 %, total balance 976.280051,
# day 1774, sell 1 unit at price 87.989998, investment 0.170767 %, total balance 1064.270049,
# day 1784, sell 1 unit at price 84.360001, investment -6.089281 %, total balance 1148.630050,
# day 1786, sell 1 unit at price 87.180000, investment -2.646569 %, total balance 1235.810050,
# day 1790: buy 1 unit at price 97.790001, total balance 1138.020049
# day 1792: buy 1 unit at price 94.050003, total balance 1043.970046
# day 1794: buy 1 unit at price 94.139999, total balance 949.830047
# day 1796, sell 1 unit at price 94.959999, investment 6.076857 %, total balance 1044.790046,
# day 1798, sell 1 unit at price 89.180000, investment -8.804582 %, total balance 1133.970046,
# day 1800: buy 1 unit at price 85.419998, total balance 1048.550048
# day 1806, sell 1 unit at price 88.820000, investment -5.560875 %, total balance 1137.370048,
# day 1808, sell 1 unit at price 87.529999, investment -7.021457 %, total balance 1224.900047,
# day 1814, sell 1 unit at price 71.029999, investment -16.846171 %, total balance 1295.930046,
# day 1818: buy 1 unit at price 67.489998, total balance 1228.440048
# day 1824, sell 1 unit at price 73.419998, investment 8.786487 %, total balance 1301.860046,
# day 1832: buy 1 unit at price 82.129997, total balance 1219.730049
# day 1834: buy 1 unit at price 81.860001, total balance 1137.870048
# day 1842, sell 1 unit at price 82.760002, investment 0.767083 %, total balance 1220.630050,
# day 1846: buy 1 unit at price 81.860001, total balance 1138.770049
# day 1848, sell 1 unit at price 85.419998, investment 4.348885 %, total balance 1224.190047,
# day 1850: buy 1 unit at price 83.959999, total balance 1140.230048
# day 1852: buy 1 unit at price 90.459999, total balance 1049.770049
# day 1854: buy 1 unit at price 89.940002, total balance 959.830047
# day 1860, sell 1 unit at price 92.099998, investment 12.509158 %, total balance 1051.930045,
# day 1862, sell 1 unit at price 89.980003, investment 7.170086 %, total balance 1141.910048,
# day 1864, sell 1 unit at price 92.669998, investment 2.443068 %, total balance 1234.580046,
# day 1874, sell 1 unit at price 92.459999, investment 2.801865 %, total balance 1327.040045,
# day 1876: buy 1 unit at price 96.059998, total balance 1230.980047
# day 1878, sell 1 unit at price 96.230003, investment 0.176978 %, total balance 1327.210050,
# day 1894: buy 1 unit at price 97.860001, total balance 1229.350049
# day 1896, sell 1 unit at price 100.480003, investment 2.677296 %, total balance 1329.830052,
# day 1908: buy 1 unit at price 94.910004, total balance 1234.920048
# day 1910, sell 1 unit at price 94.290001, investment -0.653254 %, total balance 1329.210049,
# day 1914: buy 1 unit at price 92.379997, total balance 1236.830052
# day 1922: buy 1 unit at price 95.199997, total balance 1141.630055
# day 1926: buy 1 unit at price 94.349998, total balance 1047.280057
# day 1928: buy 1 unit at price 94.169998, total balance 953.110059
# day 1930: buy 1 unit at price 92.239998, total balance 860.870061
# day 1932: buy 1 unit at price 91.870003, total balance 769.000058
# day 1934, sell 1 unit at price 90.220001, investment -2.338164 %, total balance 859.220059,
# day 1936, sell 1 unit at price 89.650002, investment -5.829827 %, total balance 948.870061,
# day 1938, sell 1 unit at price 90.489998, investment -4.091150 %, total balance 1039.360059,
# day 1940, sell 1 unit at price 89.779999, investment -4.661781 %, total balance 1129.140058,
# day 1944: buy 1 unit at price 88.599998, total balance 1040.540060
# day 1946, sell 1 unit at price 85.910004, investment -6.862526 %, total balance 1126.450064,
# day 1948, sell 1 unit at price 87.279999, investment -4.996194 %, total balance 1213.730063,
# day 1956, sell 1 unit at price 87.339996, investment -1.422124 %, total balance 1301.070059,
# day 1962: buy 1 unit at price 86.269997, total balance 1214.800062
# day 1966: buy 1 unit at price 84.309998, total balance 1130.490064
# day 1968, sell 1 unit at price 83.919998, investment -2.724005 %, total balance 1214.410062,
# day 1970: buy 1 unit at price 80.489998, total balance 1133.920064
# day 1972, sell 1 unit at price 85.099998, investment 0.937018 %, total balance 1219.020062,
# day 1982, sell 1 unit at price 99.040001, investment 23.046345 %, total balance 1318.060063,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('S&P 500 | Total gains in USD: %f, Total Investment: %f%%'%(total_gains, invest))
plt.legend()
plt.show()
